# %%
import fundamental_matrix as fmtx
import matplotlib.pyplot as plt
import numpy as np

# %%
L = fmtx.F.dot(fmtx.points_image_2[:20,:].T).T

# %%
x = np.linspace(1000,10000)
L = L / (-L[:,1,np.newaxis])
for i in range(20):
    plt.plot(x, L[i,0] * x + L[i,2])

plt.show()
